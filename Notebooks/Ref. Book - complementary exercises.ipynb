# %% [markdown]
# Here is a list of exercises selected from the reference book : College Physics. These exercises aims at complementing the exercise sessions posted on GitHub.
#
# # Chapter 1
#
# - Problems and exercises
#     - 1.2 : 9,10
#     - 1.4 : 29, 31, 33, 34
#
# # Chapter 2
#
# - Examples
#     - 2.10, 2.11, 2.13
# - Problems and exercises
#     - 2.3 : 7, 12, 14, 15
#     - 2.4 : 18
#     - 2.5 : 21, 25, 27, 29, 33, 34, 35, 40
#     - 2.7 : 41, 43, 45, 50, 54, 58
#     - 2.8 : 63, 66
#
# # Chapter 3
#
# - Examples
#     - 3.4, 3.5, 3.6
# - Conceptual questions
#     - 3.4 : 15, 16
# - Problems and exercises
#     - 3.2 : 15, 18, 21, 24
#     - 3.4 : 34, 36, 47, 49, 51
#
# # Chapter 4
#
# - Examples
#     - 4.5, 4.6, 4.7, 4.8
# - Conceptual questions
#     - 4.3 : 9, 14
#     - 4.4 : 15, 18
#     - 4.7 : 24
# - Problems and exercises
#     - 4.3 : 1, 6, 7, 8, 11, 12, 14
#     - 4.5 : 19
#     - 4.6 : 24, 27, 31, 37, 39, 49
#
# # Chapter 5
#
# - Examples
#     - 5.2
# - Problems and exercises
#     - 5.2 : 21, 22, 24, 25, 27
#
# # Chapter 6
#
# - Examples
#     - 6.1, 6.6
# - Conceptual questions
#     - 6.1 : 1
#     - 6.2 : 2
#     - 6.3 : 5
# - Problems and exercises
#     - 6.1 : 2, 4, 8
#     - 6.2 : 16, 20
#     - 6.5 : 33, 34
