# %% [markdown]
# Here is a list of exercises selected from the reference book : College Physics. These exercises aims at complementing the exercise sessions posted on GitHub (these have a "training" purpose). The exercises session posted on GitHub constitute the principal reference for the course INGE1243.
#
# # Chapter 1
#
# - Problems and exercises
#     - 1.2 : 9,10
#     - 1.4 : 29, 31, 33, 34
#
# # Chapter 2
#
# - Examples
#     - 2.10, 2.11, 2.13
# - Problems and exercises
#     - 2.3 : 7, 12, 14, 15
#     - 2.4 : 18
#     - 2.5 : 21, 25, 27, 29, 33, 34, 35, 40
#     - 2.7 : 41, 43, 45, 50, 54, 58
#     - 2.8 : 63, 66
#
# # Chapter 3
#
# - Examples
#     - 3.4, 3.5, 3.6
# - Conceptual questions
#     - 3.4 : 15, 16
# - Problems and exercises
#     - 3.2 : 15, 18, 21, 24
#     - 3.4 : 34, 36, 47, 49, 51
#
# # Chapter 4
#
# - Examples
#     - 4.5, 4.6, 4.7, 4.8
# - Conceptual questions
#     - 4.3 : 9, 14
#     - 4.4 : 15, 18
#     - 4.7 : 24
# - Problems and exercises
#     - 4.3 : 1, 6, 7, 8, 11, 12, 14
#     - 4.5 : 19
#     - 4.6 : 24, 27, 31, 37, 39, 49
#
# # Chapter 5
#
# - Examples
#     - 5.2
# - Problems and exercises
#     - 5.2 : 21, 22, 24, 25, 27
#
# # Chapter 6
#
# - Examples
#     - 6.1, 6.6
# - Conceptual questions
#     - 6.1 : 1
#     - 6.2 : 2
#     - 6.3 : 5
# - Problems and exercises
#     - 6.1 : 2, 4, 8
#     - 6.2 : 16, 20
#     - 6.5 : 33, 34
#
# # Chapter 7
#
# - Examples
#     - 7.2, 7.3, 7.4, 7.5
# - Conceptual questions
#     - 7.1 : 3
#     - 7.8 : 21
# - Problems and exercises
#     - 7.1 : 3, 4, 5, 6, 7, 8
#     - 7.2 : 9, 12, 15
#     - 7.3 : 19, 21
#     - 7.6 : 27
#     - 7.8 : 54(a)
#     - 7.9 : 69(a-b)
#
# # Chapter 8
#
# - Examples
#     - 8.4
# - Conceptual questions
#     - 8.1 : 1, 2, 3
# - Problems and exercises
#     - 8.1 : 1, 2
#     - 8.2 : 12, 21
#
# # Chapter 9
#
# - Examples
#     - 9.1
#
# # Chapter 10
#
# - Examples
#     - 10.1, 10.2, 10.3, 10.4, 10.5, 10.6, 10.7, 10.10, 10.11, 10.12, 10.14
# - Conceptual questions
#     - 10.1 : 1
#     - 10.5 : 23
# - Problems and exercises
#     - 10.1 : 1
#     - 10.4 : 28, 32
#
# # Chapter 16
#
# - Examples
#     - 16.3, 16.4, 16.5, 16.6
# - Conceptual questions
#     - 16.4 : 8
#     - 16.5 : 9
# - Problems and exercises
#     - 16.1 : 1, 2, 6
#     - 16.2 : 7, 8, 9, 10
#     - 16.3 : 14, 15
#     - 16.4 : 28, 32
#     - 16.6 : 38, 39
#
# # Chapter 18
#
# - Examples
#     - 18.1, 18.2, 18.3, 18.4, 18.5
# - Conceptual questions
#     - 18.7 : 25, 26, 27, 28, 29
# - Problems and exercises
#     - 18.1 : 1, 2, 3, 4
#     - 18.3 : 10, 11, 12, 13, 14, 15, 16, 18, 19, 21, 24, 26
#     - 18.4 : 30, 31, 32
#     - 18.7 : 41, 43, 44, 45, 46, 47, 48, 49
#
# # Chapter 19
#
# - Examples
#     - 19.3, 19.6,
# - Conceptual questions
#     - 19.1 : 3, 4, 5
# - Problems and exercises
#     - 19.1 : 1, 2, 3(a-b)
#     - 19.2 : 13, 23
#     - 19.3 : 25, 27, 28, 29
#
# # Chapter 22
#
# - Examples
#     - 22.1, 22.2
# - Conceptual questions
#     - 22.5 : 10, 11, 12
# - Problems and exercises
#     - 22.4 : 1, 2, 3, 4, 5, 6, 7
#     - 22.5 : 13, 15, 16
