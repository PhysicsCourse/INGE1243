# %% [markdown]
# # Keywords :
#
# Dimensional analysis, units, free body diagram, cartesian/polar coordinates, analogy between linear and rotation quantities, Newton's law of motion, writing vectors$*$, work-energy theorem (P.E. and K.E.), Uniform linear motion, Uniform circular motion, universal law of gravity, free fall, projectile motion, inclined plane, simple (not compound) pendulum, spring$**$, drag force, terminal velocity, electric charge, electric field, electric potential, Coulomb's law, Magnetic field, Lorentz force.
#
# ($*$) no geometry
# ($**$) no work-energy equations

# %% [markdown]
# # Question 1 ( /7)
#
# This question evaluates your ability to **look** at the same problem with **different prospectives**. It will be sequenced in 4 parts :
#
# 1. **Dimensional analysis** is used to identify the key feature(s) of the analysed motion.
# 2. Based on a **free body diagram**, a **vector-based** equation is solved to complement the output(s) of the first question.
# 3. The problem is now solved thanks to the **work-energy theorem**
# 4. Your solution is tested to realize **predictions** on a real-life example with specified parameters that are, for example, a radius, a mass, a velocity etc.
#
# Example :
#
# A familiar example is a playground swing, which acts as a pendulum. Pushing a person in a swing in time with the natural interval of the swing (its resonant frequency) makes the swing go higher and higher (maximum amplitude), while attempts to push the swing at a faster or slower tempo produce smaller arcs. This is because the energy the swing absorbs is maximized when the pushes match the swing's natural oscillations.
#
# During a walk in the winter 2023, you notice a child on a playground swing. It remembers you of your physics class where this peculiar motion was modeled by the theory of the **simple pendulum**. You sit on a nearby bench and, on a piece of paper, you depict the situation as follow :
#
# <img title="a title" alt="Alt text" src="../Figures/mock_exam/simple_pendulum.png" width="300">
#
# The pendulum has a length $L$, the attached bob is of mass $m$ and is subjected to the gravitational field at the surface of the Earth $\vec{g}$.
#
# You see that one kid is not motivated and, does nothing on the swing. His father gives him an initial angle $\theta_{0}$ and let him go with no initial velocity. Looking at the situation, you graphs two curves as follows :
#
# <img title="a title" alt="Alt text" src="../Figures/mock_exam/swing_period.png" width="500">
#
# 1. Considering the situation, what is the dynamical quantity that the 'red' curve represents ?
# 2. What is the dynamical quantity that the 'blue' curve represents ?
# 3. Are these two curves mathematically linked ?
# 4. If yes, by which mathematical operation ?
#
# After some time, you notice a significant decay. Pictured as follows :
#
# <img title="a title" alt="Alt text" src="../Figures/mock_exam/decay.png" width="500">
#
# 5. To what physical phenomenon is due this decay (the child does not move anymore after some time) ? Base your explaination on the work-energy theorem.
#
# Surprisingly, you notice that there seems to be a natural time interval in the swinging motion that you write down $T_{0}$.
#
# 5. Based on dimensional analysis, what can this $T_0$ depend on ? Can you give its expression ? Explain your reasoning.
# 6. By what factor does $T_0$ change if the length of the pendulum gets multiplied by four ?
#
# Later that day, puzzled by your observations, you plan to solve the problem. At least, a simplified version of it, you neglect all sorts of friction. Also, polar coordinates appears as a natural choice for this problem.
#
# 7. Can you write down the equation as well as the initial conditions that models the situation (without friction !) ? Remember that the inertia of the simple pendulum is $I=mL^{2}$
# 8. This equation seems a little tricky to solve. You remember that, for small angles, $sin(\theta)\approx \theta$. With this approximation, you are able to solve this equation. Give your solution.
# 9. What is the final expression of the time period $T_0$ ?
#
# The next day, on the same walk, you reach again the playground. Nevertheless, this time, there is a child on a swing that seems to explain the other "How to swing with no parents". The other kids are listening carefully... so as you.
#
# After a while, he demonstrates his swinging abilities. Here are the observation you make on the angular velocity (you are a good sketcher).
#
# <img title="a title" alt="Alt text" src="../Figures/mock_exam/resonance.png" width="700">
#
# 10. Can you comment your observations ? Why can't this child overcome 2 radians per second ? Base your explaination on the work-energy theorem.
# 11. What is the name of this phenomenon ?

# %% [markdown]
# # Question 2 ( /6)
#
# This question evaluates your ability to **identify** the relevant **concepts** required to explain an observationa and present a **justification**.
#
# Example 1 :
#
# A steel ball is attached to a string and is swung in a circular path in a horizontal plane as illustrated in the figure below.
# At point P, the string suddenly breaks near the ball. If these events are observed from directly above, which of the paths 1-5 below would the ball most closely follow after the string breaks?
#
# <img title="a title" alt="Alt text" src="../Figures/mock_exam/string.jpg" width="300">
#
# Example 2 :
#
# This diagram depicts a block sliding along a frictionless ramp.
#
# <img title="a title" alt="Alt text" src="../Figures/mock_exam/ramp.jpg" width="300">
#
# The eight numbered arrows in the diagram represent directions to be referred to when answering.
#
# - The direction of the acceleration of the block, when in position P, is best represented by which of the arrows in the diagram ?
#
#     1. Arrow 1
#     2. Arrow 2
#     3. Arrow 4
#     4. Arrow 5
#     5. None of the arrows, the acceleration is zero
#
#
# - The direction of the acceleration of the block when in position Q is best represented by which of the arrows in the diagram ?
#
#     1. Arrow 1
#     2. Arrow 3
#     3. Arrow 5
#     4. Arrow 7
#     5. None of the arrows, the acceleration is zero.
#
#
# - The direction of the acceleration of the block (after leaving the ramp) at position R is best represented by which of the arrows in the diagram ?
#
#     1. Arrow 2
#     2. Arrow 3
#     3. Arrow 5
#     4. Arrow 6
#     5. None of the arrows, the acceleration is zero.
#
# Example 3 :
#
# There is an analogy between rotational and linear physical quantities. What rotational quantities are analogous to distance and velocity ?

# %% [markdown]
# # Question 3 ( /7)
#
# This question evaluates your ability to **solve** problems with numerical inputs (**form available**).
#
# Example 1 :
#
# A football player punts the ball at an angle. Without an effect from the wind, the ball would travel 60.0 m horizontally.
#
# 1. What is the initial speed of the ball ?
# 2. When the ball is near its maximum height it experiences a brief gust of wind that reduces its horizontal velocity by 1.50 m/s. What distance does the ball travel horizontally ?
#
# Example 2 :
#
# A marble is placed at the top of a prototyped roller-coaster as depicted on the following figure. Its initial velocity is zero.
#
# <img title="a title" alt="Alt text" src="../Figures/mock_exam/loop.png" width="400">
#
# 1. What is the minimum height $h$ of a slope that must be constructed in order for a particle of mass $m=1\;kg$ to complete the loop with a radius $R\;=\;10\;m$ safely, assuming a **frictionless** trip?
# 2. What is the minimum height with a mass of $2\;kg$ ?
#
#
# Example 3 :
#
# Three positive point charges, of respectively +1, +2 and +3 micro-coulombs, are located on a plane as depicted on the following figure :
#
# <img title="a title" alt="Alt text" src="../Figures/mock_exam/charges_vector.png" width="400">
#
# Suppose that a negative charge of -1 micro-coulombs is placed at the intercection of the three dashed lines (blue point - the origin of the carthesian coordinate system). Find the magnitude and orientation of net force acting on this negative charge.
