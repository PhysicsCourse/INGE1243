# %% [markdown]
# # Exercise 1
#
# You are given three vectors in 3D space,
#
# $$\vec{a}=3\;\textbf{e}_{x}+2\;\textbf{e}_{y}-\;\textbf{e}_{z}$$
#
# $$\vec{b}=2\;\textbf{e}_{x}-\;\textbf{e}_{y}+\;\textbf{e}_{z}$$
#
# $$\vec{c}=\;\textbf{e}_{x}+3\;\textbf{e}_{y}$$
#
# Find
#
# 1. $\vec{a}+\vec{b}$
# 2. $\vec{a}-\vec{b}$
# 3. $a_{x}$
# 4. $\vec{a}\cdot\textbf{e}_{x}$
# 5. $\vec{a}\cdot\vec{b}$
# 6. $(\vec{a}\cdot\vec{c})\vec{b}-(\vec{a}\cdot\vec{b})\vec{c}$

# %% [markdown]
# # Exercise 2
#
# A cube is placed so that one corner is at the origin and the three edges are along the x-, y- and z-axes of a carthesian coordinate system (see image below). Use vectors to compute:
#
# 1. The angle between the edge along the z-axis (line ab) and the diagonal from the origin to the opposite corner (line ad).
# 2. the angle between line ac (the diagonal of a face) and line ad.
#
# <img title="a title" alt="Alt text" src="../Figures/Exercices 3/cube.jpg" width="300">

# %% [markdown]
# # Exercise 3
#
# On 26 and 27 September 2022, the Nord Stream 1 and 2 gas pipelines were victims of major gas leaks, manifested on the surface of the Baltic Sea. Both pipelines were shutted down, but remained full of gas in order to maintain pressure. Between the end of september and mid-october, The NGO "Environmental Defense Fund" estimates that these leaks released 115,000 tons of methane into the atmosphere, the equivalent of nearly 10 Mt (million tons) of CO2, with the same impact on the climate as the annual emissions of 2 million gasoline cars.
#
# Methane ($CH_{4}$) is thus worth studying. Particularly, Methane's geometrical parameters are at the root of quantum chemistry. Given that any $C-H$ covalent bond is 108.7 picometers, use a carthesian coordinate system and vectors to find:
#
# 1. The angle defined by the 2 covalent bonds $H_{1}-C-H_{2}$.
# 2. The distance between two hydrogen atoms.
#
# <img title="a title" alt="Alt text" src="../Figures/Exercices 3/methane.jpg" width="300">

# %% [markdown]
# # Exercises (reference textbook)
#
# You can find these exercises in the reference book (College Physics) at page 136: PROBLEMS & EXERCISES:
#
# - 3.2 Vector Addition and Subtraction: Graphical Methods
#
# exercises: 5, 10 (try to derive the law of cosine using the "dot product"), 11, 12 (write down the expression of the "new" unit vectors $\textbf{e}_{x'}$ and $\textbf{e}_{y'}$)
#
# - 3.3 Vector Addition and Subtraction: Analytical Methods
#
# exercises: 22

# %% [markdown]
# # Exercice 4
#
# Why is the couple (T,h) (where T is your body temperature and h, your height) not the components of a vector ? (try to answer without looking at your notes)

# %% [markdown]
# # Exercice 5
#
# A particle is initially at a point $\vec{r}_{0}$, and is moving under gravity with an initial velocity $\vec{v}_{0}$. Find the subsequent motion $\vec{r}(t)$.

# %% [markdown]
# # Exercise 6
#
# Due to a massive internet breakdown, a huge number of wikipedia pages have been corrupted. Your mission, should you choose to accept it, is to complete the missing formulas in this page. Don't hesitate to complement this work with figures that you constructed yourself or as a team. Good luck !
#
#
# ### Kinematics: Projectile motion
#
# In projectile motion, the horizontal motion and the vertical motion are independent of each other; that is, neither motion affects the other (pay attention to the synchronization of the balls hitting the ground in this video: https://www.youtube.com/watch?v=zMF4CD7i3hg). This is the principle of compound motion established by Galileo in 1638, and used by him to prove the parabolic form of projectile motion.
#
# The horizontal and vertical components of a projectile's velocity are independent of each other.
# A ballistic trajectory is a parabola with homogeneous acceleration, such as in a space ship with constant acceleration in absence of other forces. On Earth the acceleration changes magnitude with altitude and direction with latitude/longitude. This causes an elliptic trajectory, which is very close to a parabola on a small scale. In this article a homogeneous acceleration is assumed and we neglect air resistance on the projectile.
#
# ### Acceleration
# Since there is only acceleration in the vertical direction, the velocity in the horizontal direction is constant, being equal to $|\vec{v}_{0}|cos(\theta_{0})$ (with $\theta_{0}$, the initial launch angle). The vertical motion of the projectile is the motion of a particle during its free fall. Here the acceleration is constant, being equal in magnitude to **???(1)**. The components of the acceleration are:
#
# $$a_{x}= \textbf{???(2)}$$
# $$a_{y}=\textbf{???(3)}$$
#
# ### Velocity
# Let the projectile be launched with an initial velocity $\vec{v}(t=0)$ which can be expressed as the sum of horizontal and vertical components as follows:
#
# $$\vec{v}(t=0)=v_{0x}\;\textbf{e}_{x}+v_{0y}\;\textbf{e}_{y}$$
#
# The components $v_{0x}$ and $v_{0y}$ can be found if the initial launch angle, $\theta_{0}$ , is known:
#
# $$v_{0x}=\textbf{???(4)}$$
# $$v_{0y}=\textbf{???(5)}$$
#
# The horizontal component of the velocity of the object **((6) change or does not change)** throughout the motion. The vertical component of the velocity changes linearly, because the acceleration due to gravity is constant. The accelerations in the x and y directions can be be used to solve for the components of velocity at any time $t$, as follows:
#
# $$v_{x}(t)= \textbf{???(7)}$$
# $$v_{y}(t)=\textbf{???(8)}$$
#
# The magnitude of the velocity (under the Pythagorean theorem):
#
# $|\vec{v}(t)|=\textbf{???(9)}$
#
# ### Position
#
# At any time $t$, the projectile's horizontal and vertical displacement are:
#
# $$x(t)=\textbf{???(10)}$$
# $$y(t)=\textbf{???(11)}$$
#
# If $t$ is eliminated between these two equations the following equation is obtained:
#
# $$y-y_{0} = (\textbf{???(12)})(x-x_{0})-(\textbf{???(13)})(x-x_{0})^{2} $$
#
# Since $g$, $\theta$, and $v_{0}=|\vec{v}(t=0)|$ are constants, the above equation is of the form:
#
# $$y-y_{0}= \textbf{???(14)}$$
#
# in which a and b are constants. This is the equation of a parabola, so the path is parabolic. The axis of the parabola is vertical.
#
# ### Properties of the trajectory
#
# #### Time of flight or total time of the whole journey
#
# The total time $T$ for which the projectile remains in the air is called the time of flight. We consider here $x_{0}=0$ and $y_{0}=0$.
#
# After the flight, the projectile returns to the horizontal axis (x-axis), so the equation defining $T$ is
#
# $$y(T)=0$$
#
# Which gives:
#
# $$T=\textbf{???(15)}$$
#
# [extradiegetic note: Is this consistent with the "dimensional analysis" method of exercise 1, session 1 ?]
#
# #### Maximum height of projectile
#
# The greatest height that the object will reach is known as the peak of the object's motion. The increase in height will last until time $T^{*}$, where $v_{y}(T^{*})=0$. That is :
#
# $$v_{y}(T^{*})=0=\textbf{???(16)}$$
#
# leading to:
#
# $$T^{*}=\textbf{???(17)}$$
#
# This is obviously a half of $T$.
#
# For the vertical displacement of the maximum height $h$ of projectile:
#
# $$h=v_{0}T^{*}sin(\theta_{0})-\frac{1}{2}g(T^{*})^{2}$$
#
# $$h=\frac{v_{0}^{2}sin^{2}(\theta_{0})}{2g}$$
#
# The maximum reachable height is obtained for $\theta_{0}=\pi/2$
#
# #### Maximum distance of projectile
#
# This section was completely erased from the internet... Try to write it down yourself and propose me something that I can post on moodle. You can get inspired by the previous section. The following two sentences have to appear in your text:
#
# The horizontal range $d$ of the particle is given by $\textbf{(18)}$).
# The initial angle to get a maximum distance is: $\textbf{(19)}$
#
# [extradiegetic note: Is this consistent with the "dimensional analysis" method of exercise 1, session 1 ?]
